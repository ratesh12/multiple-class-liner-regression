# %% [markdown]
# # Penguins peoject prediction

# %% [markdown]
# # Step1:Import Libararies

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # step2: Load dataset

# %%
ww=pd.read_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\jup\\muliclass logestic.penguins\\penguins.csv")
ww.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %% [markdown]
# # plot graph

# %%
import seaborn as sns

# %%
sns.pairplot(ww)

# %% [markdown]
# # Step 3: Data Analysis/Data Handling/Data Modififcation/Data Cleaning

# %%
ww[ww.isnull().any(axis=1)]
# Out:
#       id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3      3  Adelie  Torgersen             NaN            NaN                NaN
# 8      8  Adelie  Torgersen            34.1           18.1              193.0
# 9      9  Adelie  Torgersen            42.0           20.2              190.0
# 10    10  Adelie  Torgersen            37.8           17.1              186.0
# 11    11  Adelie  Torgersen            37.8           17.3              180.0
# 47    47  Adelie      Dream            37.5           18.9              179.0
# 178  178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# ...

# %%
ww.dropna(inplace = True)

# %%
ww.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 333 non-null    int64
#  1   species            333 non-null    object
#  2   island             333 non-null    object
#  3   bill_length_mm     333 non-null    float64
#  4   bill_depth_mm      333 non-null    float64
#  5   flipper_length_mm  333 non-null    float64
#  6   body_mass_g        333 non-null    float64
#  7   sex                333 non-null    object
#  8   year               333 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 26.0+ KB

# %%
ww[ww.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []

# %% [markdown]
# # Step 4: Seperate input and output in different variables

# %%
ll = LabelEncoder()
ww["species"]=ll.fit_transform(ww["species"])
ww["island"]=ll.fit_transform(ww["island"])
ww["sex"]=ll.fit_transform(ww["sex"])
ww
# Out:
#       id  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0        0       2            39.1           18.7              181.0
# 1      1        0       2            39.5           17.4              186.0
# 2      2        0       2            40.3           18.0              195.0
# 4      4        0       2            36.7           19.3              193.0
# 5      5        0       2            39.3           20.6              190.0
# ..   ...      ...     ...             ...            ...                ...
# 339  339        1       1            55.8           19.8              207.0
# 340  340        1       1            43.5           18.1              202.0
# 341  341        1       1            49.6           18.2              193.0
# 342  342        1       1            50.8           19.0              210.0
# 343  343        1       1            50.2           18.7              198.0
#
#      body_mass_g  sex  year
# ...

# %%
x=ww.drop(columns=["species"])
x
# Out:
#       id  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0       2            39.1           18.7              181.0
# 1      1       2            39.5           17.4              186.0
# 2      2       2            40.3           18.0              195.0
# 4      4       2            36.7           19.3              193.0
# 5      5       2            39.3           20.6              190.0
# ..   ...     ...             ...            ...                ...
# 339  339       1            55.8           19.8              207.0
# 340  340       1            43.5           18.1              202.0
# 341  341       1            49.6           18.2              193.0
# 342  342       1            50.8           19.0              210.0
# 343  343       1            50.2           18.7              198.0
#
#      body_mass_g  sex  year
# 0         3750.0    1  2007
# 1         3800.0    0  2007
# 2         3250.0    0  2007
# 4         3450.0    0  2007
# ...

# %%
y=ww.iloc[:,1]
y
# Out:
# 0      0
# 1      0
# 2      0
# 4      0
# 5      0
#       ..
# 339    1
# 340    1
# 341    1
# 342    1
# 343    1
# Name: species, Length: 333, dtype: int64

# %% [markdown]
# # Step 5:Split input output data in training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size= 0.2,random_state= 42)

# %% [markdown]
# # Step6: Import Algorithm

# %%
from sklearn. linear_model import LogisticRegression
pen=LogisticRegression()

# %% [markdown]
# # Step 7: Model Train(.fit()) and Prediction(.predict())

# %%
pen.fit(x_train,y_train)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=pen.predict(x_test)

# %% [markdown]
# # Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0
